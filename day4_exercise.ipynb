# %% [markdown]
# """
# **Project 1: Grocery List Manager**
#
# Objective:
# Create a simple grocery list manager where users can add items, view the list, and remove duplicates (using set functionality).
#
# Steps:
# Ask the user to input grocery items (comma-separated).
# Store these items in a list.
# Convert the list to a set to remove duplicates.
# Display the updated grocery list.
# """

# %%
# User shopping items list
user_items = input("Enter your shopping items separated by commas: ")

# Store user items in a variable and strip of white spaces
user_list = user_items.strip().split(",")

# Convert the items to a set
new_set = set(user_list)
# Print the items
print(f"Here is your shopping list {new_set}")
# Out:
# Here is your shopping list {'onions', 'tomato', 'potato', 'garlic'}
