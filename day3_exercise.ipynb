# %% [markdown]
# ### Exercises Day3:
#
# 1. **First Three Letters of a Name**
#    - Take a user's full name as input, and print the first three letters of their first name and the first three letters of their last name.
#
# 2. **Reverse a Word**
#    - Take a word as input and print the reversed word using slicing.
#
# 3. **Extract the Middle Character**
#    - Take an odd-length string as input and print the middle character using slicing.
#
# 4. **Count Characters (Excluding Spaces)**
#    - Take a sentence as input and count the number of characters, excluding spaces.
#
# 5. **Modify User Input**
#    - Ask the user for their favorite color and output the color in lowercase, uppercase, and with spaces removed.
#
# 6. **Username Generator**
#    - Take the user's full name and generate a username using the first three letters of the first name and the last three letters of the last name.
#
# 7. **Strip Leading and Trailing Spaces**
#    - Take a string with extra spaces and remove all the leading and trailing spaces using `strip()`.
#
# 8. **Uppercase Initials**
#    - Take a full name as input and print the initials in uppercase.
#
# 9. **Check if a Word is a Palindrome**
#    - Take a word as input and check whether it is a palindrome.
#
# 10. **Find the Last Three Characters**
#     - Take a word as input and print the last three characters using slicing.
#
# ---
#
# ### Mini Project: **Password Strength Checker**
#
# **Goal**:
# Create a program that takes a user's input for a password and checks its strength based on the following criteria:
# - At least 8 characters long.
# - Contains both uppercase and lowercase letters.
# - Includes at least one numeric digit.
# - Contains at least one special character (e.g., `!`, `@`, `#`, etc.).
#
# **Steps**:
# 1. Take the password as input from the user.
# 2. Use string methods like `.lower()`, `.isupper()`, `.isdigit()`, and slicing to validate the password.
# 3. Print whether the password is weak, medium, or strong based on how many criteria it satisfies.

# %%
# Take a user's full name as input, and print the first three letters of their first name 
# and the first three letters of their last name.
full_name = input("What is your full name: ").strip()
parts = full_name.split()

if len(parts) < 2:
    print("Please enter both a first and last name.")
else:
    first_name = parts[0]
    last_name = parts[-1]

    print(
        f"First 3 letters: {first_name[:3]}, "
        f"Last 3 letters: {last_name[:3]}"
    )
# Out:
# First 3 letters: Kep, Last 3 letters: Mut

# %%
# **Reverse a Word**  
# - Take a word as input and print the reversed word using slicing.
user_word = input("Enter a word: ").strip()


reverse_word = user_word[::-1]
print(reverse_word)
# Out:
# rehpek

# %%
#Take the user's first and last name as input.  
#Generate a gmail_id for the user by concatenating the first three letters of the   first name and the last three letters of the last name with domain @gmail.com 
#Ensure the username is lowercase and has no spaces.  
user_name = input("Enter your full name").lower()

first_name, last_name = user_name.split()

first_name_three_letters =first_name[:3]
last_name_three_letters =last_name[:3]

email_id =f"Your email is {first_name_three_letters}{last_name_three_letters}@gmail.com"
print(email_id)
# Out:
# Your email is kepash@gmail.com

# %%
# **Extract the Middle Character**  
# Take an odd-length string as input and print the middle character using slicing.
string = input("Enter an odd length string: ").lower().strip()
string_length = len(string)
middle_index = string_length // 2
middle_character = string[middle_index]
middle_character
# Out:
# 'p'

# %%
# **Count Characters (Excluding Spaces)**  
# Take a sentence as input and count the number of characters, excluding spaces.
sentence = input("Enter a sentence: ").strip()

individual_words = sentence.split()

num_words = len(individual_words)

print(num_words)
# Out:
# 4

# %%
# **Modify User Input**  
#Ask the user for their favorite color and 
#output the color in lowercase, uppercase, and with spaces removed.
fav_colour = input("What is your favourite colour: ").strip()

lower_case = fav_colour.lower()
upper_case = fav_colour.upper()

print(lower_case)
print(upper_case)
# Out:
# blue
# BLUE

# %%
# **Username Generator**  
# Take the user's full name and generate a username 
# using the first three letters of the first name and the last three letters of the last name.
first_name = input("Enter your first name: ").strip().lower()
last_name = input("Enter your last name: ").strip().lower()

first_three_letas = first_name[0:3]
last_three_letas = last_name[-3:]

user_name = (f"Your user name is '{first_three_letas}{last_three_letas}'")
print(user_name)
# Out:
# Your user name is 'keplis'

# %%
#**Strip Leading and Trailing Spaces**  
# Take a string with extra spaces and remove all the leading and trailing spaces using `strip()`.

word = "     Python    "
print(word.strip())
# Out:
# Python

# %%
# **Check if a Word is a Palindrome**  
#Take a word as input and check whether it is a palindrome.

user_word = input("Enter a word: ").strip().lower()

if user_word == user_word[::-1]:
    print(f"Your word {user_word} is a palindrome")
else:
    print(f"Your word {user_word} is not a palindrome")
# Out:
# Your word kepjhe is not a palindrome

# %%
#**Find the Last Three Characters**  
# Take a word as input and print the last three characters using slicing.

user_input = input("Enter a word: ")

last_three_chars = user_input[-3:]

print(last_three_chars)
# Out:
# aya

# %% [markdown]
# ### Mini Project: **Password Strength Checker**
#
# **Goal**:
# Create a program that takes a user's input for a password and checks its strength based on the following criteria:
# - At least 8 characters long.
# - Contains both uppercase and lowercase letters.
# - Includes at least one numeric digit.
# - Contains at least one special character (e.g., `!`, `@`, `#`, etc.).
#
# **Steps**:
# 1. Take the password as input from the user.
# 2. Use string methods like `.lower()`, `.isupper()`, `.isdigit()`, and slicing to validate the password.
# 3. Print whether the password is weak, medium, or strong based on how many criteria it satisfies.

# %%
user_password = input("Enter your password: ")

has_upper = False
has_lower = False
has_digit = False
has_special = False

password_length = len(user_password)

for char in user_password:
    if char.isupper():
        has_upper = True
    elif char.islower():
        has_lower = True
    elif char.isdigit():
        has_digit = True
    elif not char.isalnum():
        has_special = True

if has_upper and has_lower and has_digit and has_special and password_length > 8:
    print("Valid Password")
else:
    print("Password not valid")
# Out:
# Password not valid
